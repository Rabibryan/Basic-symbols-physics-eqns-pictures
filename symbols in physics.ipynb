# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# # Mechanics

# %% [markdown]
# ## Laws of motion

# %% [markdown]
# ### First law of moton gives the definition of force whereas second law gives the measurement of force

# %% [markdown]
# # Mathematical symbols

# %% [markdown]
# $\alpha$

# %% [markdown]
# $\beta$

# %% [markdown]
# $\gamma$

# %% [markdown]
# $\nabla$

# %% [markdown]
# $\eta$

# %% [markdown]
# $\tau$

# %% [markdown]
# ![img](data:image/jpeg;base64,...)

# %% [markdown]
# ![img](data:image/jpeg;base64,...)

# %% [markdown]
# various symbols

# %% [markdown]
# $\epsilon$

# %% [markdown]
# $\epsilon_0$

# %% [markdown]
# $\rho$

# %% [markdown]
# $\delta$

# %% [markdown]
# $\nabla$

# %% [markdown]
# $\chi$

# %% [markdown]
# $\tau$

# %% [markdown]
# $\theta$

# %% [markdown]
# $\sigma$

# %% [markdown]
# $\sigma_0$

# %% [markdown]
# $\omega$

# %% [markdown]
# $\omega_4$

# %% [markdown]
# $\sqrt5$

# %% [markdown]
# $\xi$

# %% [markdown]
# $\xi_1$

# %% [markdown]
# $\alpha^3$
